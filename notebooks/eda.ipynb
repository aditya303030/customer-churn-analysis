# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_customers_dataset.csv')
geolocation = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_geolocation_dataset.csv')
order_items = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_order_items_dataset.csv')
order_payments = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_order_payments_dataset.csv')
order_reviews = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_order_reviews_dataset.csv')
orders = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_orders_dataset.csv')
products = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_products_dataset.csv')
sellers = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/olist_sellers_dataset.csv')
product_category = pd.read_csv('/Users/aditya/Desktop/customer-intelligence-platform/data/raw/product_category_name_translation.csv')

# %%
customers.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000
